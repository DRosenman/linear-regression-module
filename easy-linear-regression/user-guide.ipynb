# %% [markdown]
# # Step By Step Linear Regression Module Tutorial
#
# ## Getting Started
#
# First, make sure that you save the linear regresion module file, , in the same folder that your jupyter notebook is in.
#
# Next, include the following statements at the top of your notebook's first code cell:

# %%
import linear_regression as lr
# %matplotlib notebook
import matplotlib.pyplot as plt

# %% [markdown]
# ## Creating Dataset Object
# ### Creating dataset object from a list of x-coordinates and a list of y-coordinates:
# If you have n datapoints (x1,y1),(x2,y2),...,(xn,yn)
#
#
# ```python
# x = [x1,x2,...,xn]
# y = [y1,y2,...,yn]
#
# datasetname = lr.dataset(x,y)
# ```
#
# *Example:* Data points: (1.0,10.2),(2.0,15.3),(3.0,30.3),(4.0,45.2)

# %%
#Data points: (1.0,10.2),(2.0,15.3),(3.0,30.3),(4.0,45.2)
x_coordinates = [1.0,2.0,3.0,4.0]
y_coordinates = [10.2,15.3,30.3,45.2]

dataset1 = lr.dataset(x_coordinates,y_coordinates)

# %% [markdown]
# ### Creating dataset object from a single list of data points:
# If you have n datapoints (x1,y1),(x2,y2),...,(xn,yn)
#
#
# ```python
# datapoints = [(x1,y1),(x2,y2),...,(xn,yn)]
#
# datasetname = lr.dataset(datapoints)
# ```
#
# *Example:* Data points: (1.0,10.2),(2.0,15.3),(3.0,30.3),(4.0,45.2)

# %%
#Data points: (1.0,10.2),(2.0,15.3),(3.0,30.3),(4.0,45.2)
points = [(1.0,10.2),(2.0,15.3),(3.0,30.3),(4.0,45.2)]
daves_data = lr.dataset(points)

# %% [markdown]
# ## Printing Regression Results
# ```python
# print(datasetname)
# ```
#
# *Example:*

# %%
#Using the dataset named 'dave_date' created above
print(daves_data)
# Out:
# LINEAR LEAST-SQUARES REGRESSION ANALYSIS
#
# BEST FIT LINE:
# slope = 12.0
# intercept = -4.75
# std. error, slope = 1.7032322214
# std. error, intercept = 4.66449354164
# r-squared = 0.980443203309
# number of data points = 4
#
# BEST FIT LINE THROUGH THE ORIGIN, (0,0):
# slope = 10.4166666667
# intercept = 0.0
# std. error, slope = 0.699616296954
# std. error, intercept = N//A
# r-squared = 0.993301573551
# number of data points = 4

# %% [markdown]
# ## Displaying Graph
# ### Basic Graph
# ```python
# plt.figure()
# davesetname.graph()
# ```
#
# *Example*:

# %%
#Using the previously credited dataset named 'daves_data'
plt.figure()
daves_data.graph()
# Out:
# <img src="data:image/png;base64,..." width="639.8499802953507">

# %% [markdown]
# ### Graph With Best Fit Line Through (0,0)
# ```python
# plt.figure()
# datasetname.graph(through_origin = True)
# ```
#
# *Example*:

# %%
#Using the previously credited dataset named 'daves_data'
plt.figure()
daves_data.graph(through_origin = True)
# Out:
# <img src="data:image/png;base64,..." width="639.8499802953507">

# %% [markdown]
# # ADDITIONAL FEATURES COMING SOON
